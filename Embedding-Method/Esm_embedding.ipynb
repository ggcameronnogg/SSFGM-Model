# %%
import torch
import esm
import os
from Bio import SeqIO
import numpy as np 
device = torch.device("cpu")

model_name = 'esm2_t36_3B_UR50D'
model, alphabet = esm.pretrained.load_model_and_alphabet(model_name)
model = model.to(device)  
model.eval()
fasta_path = 'DECOY_train.fasta'
output_directory = 'esm_ebd_DECOY_train'
os.makedirs(output_directory, exist_ok=True)

with open(fasta_path, 'r') as fasta_file:
    for record in SeqIO.parse(fasta_file, "fasta"):
        sequence = str(record.seq)
        data = [(record.id, sequence)]

        batch_converter = alphabet.get_batch_converter()
        batch_labels, batch_strs, batch_tokens = batch_converter(data)
        batch_tokens = batch_tokens.to(device) 

        with torch.no_grad():
            results = model(batch_tokens, repr_layers=[33], return_contacts=False)
        
        tokens_embs = results['representations'][33].cpu().numpy() 

        np.save(os.path.join(output_directory, f'{record.id}.npy'), tokens_embs)
        print(f'Saved embeddings for {record.id}')
# Out:
# Saved embeddings for UniRef50_Q75A74
# Saved embeddings for UniRef50_Q9Y7U9
# Saved embeddings for UniRef50_Q17Q32
# Saved embeddings for UniRef50_Q8IYA6
# Saved embeddings for UniRef50_A5ULG2
# Saved embeddings for UniRef50_Q8F4J6
# Saved embeddings for UniRef50_Q54PQ8
# Saved embeddings for UniRef50_P25693
# Saved embeddings for UniRef50_Q02750
# Saved embeddings for UniRef50_Q12468
# Saved embeddings for UniRef50_Q54X97
# Saved embeddings for UniRef50_Q9USY1
# Saved embeddings for UniRef50_Q3AAM5
# Saved embeddings for UniRef50_Q8X7U4
# Saved embeddings for UniRef50_Q9RT22
# Saved embeddings for UniRef50_O75891
# Saved embeddings for UniRef50_O93967
# Saved embeddings for UniRef50_Q99MV1
# Saved embeddings for UniRef50_Q9RYK1
# Saved embeddings for UniRef50_O14185
# Saved embeddings for UniRef50_Q5KBP2
# Saved embeddings for UniRef50_A2CEH0
# Saved embeddings for UniRef50_Q6BU18
# Saved embeddings for UniRef50_P38529
# Saved embeddings for UniRef50_Q9NZD8
# Saved embeddings for UniRef50_Q4JBG0
# Saved embeddings for UniRef50_Q757E3
# Saved embeddings for UniRef50_Q9P791
# Saved embeddings for UniRef50_P0CO13
# Saved embeddings for UniRef50_P0C2T1
# Saved embeddings for UniRef50_Q6F9N7
# Saved embeddings for UniRef50_P22133
# Saved embeddings for UniRef50_P33764
# Saved embeddings for UniRef50_O14468
# Saved embeddings for UniRef50_O60099
# Saved embeddings for UniRef50_Q8SQK9
# Saved embeddings for UniRef50_Q9USM4
# Saved embeddings for UniRef50_Q9UKT4
# Saved embeddings for UniRef50_Q2SDQ0
# Saved embeddings for UniRef50_Q14139
# Saved embeddings for UniRef50_P78014
# Saved embeddings for UniRef50_O15604
# Saved embeddings for UniRef50_Q5ZVA8
# Saved embeddings for UniRef50_Q9XHH2
# Saved embeddings for UniRef50_Q6PRD7
# Saved embeddings for UniRef50_A4Q9F3
# Saved embeddings for UniRef50_Q3INV7
# Saved embeddings for UniRef50_Q5E9Y6
# Saved embeddings for UniRef50_O25773
# Saved embeddings for UniRef50_O74793
# Saved embeddings for UniRef50_Q6PCD5
# Saved embeddings for UniRef50_Q9WUU8
# Saved embeddings for UniRef50_P35270
# Saved embeddings for UniRef50_Q9P0K7
# Saved embeddings for UniRef50_Q81II2
# Saved embeddings for UniRef50_P59046
# Saved embeddings for UniRef50_A5URM3
# Saved embeddings for UniRef50_Q49MI3
# Saved embeddings for UniRef50_A6LC43
# Saved embeddings for UniRef50_Q82UK8
# Saved embeddings for UniRef50_Q9LPG6
# Saved embeddings for UniRef50_O83128
# Saved embeddings for UniRef50_P25294
# Saved embeddings for UniRef50_Q9UUC7
# Saved embeddings for UniRef50_P0DJ19
# Saved embeddings for UniRef50_Q9US47
# Saved embeddings for UniRef50_E7F9T0
# Saved embeddings for UniRef50_O17581
# Saved embeddings for UniRef50_F4JY37
# Saved embeddings for UniRef50_C0HK24
# Saved embeddings for UniRef50_Q9PR88
# Saved embeddings for UniRef50_P37094
# Saved embeddings for UniRef50_Q03Q51
# Saved embeddings for UniRef50_Q6MAG9
# Saved embeddings for UniRef50_Q5GTG5
# Saved embeddings for UniRef50_P34893
# Saved embeddings for UniRef50_O43548
# Saved embeddings for UniRef50_Q02197
# Saved embeddings for UniRef50_P36162
# Saved embeddings for UniRef50_O94378
# Saved embeddings for UniRef50_Q9H987
# Saved embeddings for UniRef50_P36395
# Saved embeddings for UniRef50_A8IVX2
# Saved embeddings for UniRef50_Q45EK7
# Saved embeddings for UniRef50_P60837
# Saved embeddings for UniRef50_P0CQ01
# Saved embeddings for UniRef50_P47707
# Saved embeddings for UniRef50_A6Q573
# Saved embeddings for UniRef50_Q91690
# Saved embeddings for UniRef50_P0A9H8
# Saved embeddings for UniRef50_P40048
# Saved embeddings for UniRef50_Q6FIN2
# Saved embeddings for UniRef50_Q9Z5U2
# Saved embeddings for UniRef50_Q23571
# Saved embeddings for UniRef50_P09467
# Saved embeddings for UniRef50_Q9WTZ9
# Saved embeddings for UniRef50_P81021
# Saved embeddings for UniRef50_Q9UGI0
# Saved embeddings for UniRef50_Q46871
# Saved embeddings for UniRef50_O77460
# Saved embeddings for UniRef50_P00374
# Saved embeddings for UniRef50_B5ZBV6
# Saved embeddings for UniRef50_Q23261
# Saved embeddings for UniRef50_Q54340
# Saved embeddings for UniRef50_Q9K7R6
# Saved embeddings for UniRef50_Q8Y5X6
# Saved embeddings for UniRef50_Q14BB9
# Saved embeddings for UniRef50_O43137
# Saved embeddings for UniRef50_Q2QAV0
# Saved embeddings for UniRef50_Q6PGH2
# Saved embeddings for UniRef50_Q55EL2
# Saved embeddings for UniRef50_B0S4Q5
# Saved embeddings for UniRef50_Q9HGL6
# Saved embeddings for UniRef50_Q4JXF0
# Saved embeddings for UniRef50_Q1MA75
# Saved embeddings for UniRef50_P94212
# Saved embeddings for UniRef50_O60139
# Saved embeddings for UniRef50_Q6FEP2
# Saved embeddings for UniRef50_E7RAM2
# Saved embeddings for UniRef50_O15061
# Saved embeddings for UniRef50_C6C0N2
# Saved embeddings for UniRef50_Q9NWZ8
# Saved embeddings for UniRef50_Q9SKN2
# Saved embeddings for UniRef50_P53890
# Saved embeddings for UniRef50_B8C4D7
# Saved embeddings for UniRef50_P9WF36
# Saved embeddings for UniRef50_Q6CWX7
# Saved embeddings for UniRef50_B1YI19
# Saved embeddings for UniRef50_A8GLJ4
# Saved embeddings for UniRef50_Q6DA21
# Saved embeddings for UniRef50_A0KNH6
# Saved embeddings for UniRef50_Q9H0Z9
# Saved embeddings for UniRef50_P0DM85
# Saved embeddings for UniRef50_F4I5N6
# Saved embeddings for UniRef50_A5UZG3
# Saved embeddings for UniRef50_Q9NSP4
# Saved embeddings for UniRef50_Q9P6J4
# Saved embeddings for UniRef50_O74561
# Saved embeddings for UniRef50_Q6MUM7
# Saved embeddings for UniRef50_I3R636
# Saved embeddings for UniRef50_Q55CL6
# Saved embeddings for UniRef50_Q8A2N9
# Saved embeddings for UniRef50_Q83MQ1
# Saved embeddings for UniRef50_Q5BQN5
# Saved embeddings for UniRef50_Q1GK69
# Saved embeddings for UniRef50_B1L5R5
# Saved embeddings for UniRef50_Q8XW28
# Saved embeddings for UniRef50_P94433
# Saved embeddings for UniRef50_P11309
# Saved embeddings for UniRef50_Q13042
# Saved embeddings for UniRef50_Q09LX1
# Saved embeddings for UniRef50_O94925
# Saved embeddings for UniRef50_Q6CGK4
# Saved embeddings for UniRef50_O74965
# Saved embeddings for UniRef50_Q6C715
# Saved embeddings for UniRef50_Q4PEV8
# Saved embeddings for UniRef50_Q14749
# Saved embeddings for UniRef50_P47209
# Saved embeddings for UniRef50_Q89AP1
# Saved embeddings for UniRef50_A7HVT8
# Saved embeddings for UniRef50_Q52880
# Saved embeddings for UniRef50_Q5XAW2
# Saved embeddings for UniRef50_O94384
# Saved embeddings for UniRef50_Q9P6K4
# Saved embeddings for UniRef50_B9LPF8
# Saved embeddings for UniRef50_O34171
# Saved embeddings for UniRef50_B4F103
# Saved embeddings for UniRef50_Q10579
# Saved embeddings for UniRef50_Q9US34
# Saved embeddings for UniRef50_P23497
# Saved embeddings for UniRef50_O07938
# Saved embeddings for UniRef50_Q9VQS5
# Saved embeddings for UniRef50_P0AC71
# Saved embeddings for UniRef50_P41142
# Saved embeddings for UniRef50_Q54LV1
# Saved embeddings for UniRef50_Q08686
# Saved embeddings for UniRef50_Q05BV3
# Saved embeddings for UniRef50_Q9WYG8
# Saved embeddings for UniRef50_O51087
# Saved embeddings for UniRef50_Q9K0Z1
# Saved embeddings for UniRef50_Q9PE42
# Saved embeddings for UniRef50_O14170
# Saved embeddings for UniRef50_Q90YJ2
# Saved embeddings for UniRef50_Q04093
# Saved embeddings for UniRef50_Q16LW2
# Saved embeddings for UniRef50_Q02790
# Saved embeddings for UniRef50_Q4FUZ9
# Saved embeddings for UniRef50_Q8EV76
# Saved embeddings for UniRef50_Q1IMM4
# Saved embeddings for UniRef50_P39643
# Saved embeddings for UniRef50_Q04601
# Saved embeddings for UniRef50_Q5U243
# Saved embeddings for UniRef50_B0UBI6
# Saved embeddings for UniRef50_B8A9B2
# Saved embeddings for UniRef50_P0C348
# Saved embeddings for UniRef50_F4KFT7
# Saved embeddings for UniRef50_Q04949
# Saved embeddings for UniRef50_B1GZY8
# Saved embeddings for UniRef50_Q7UJD7
# Saved embeddings for UniRef50_Q10474
# Saved embeddings for UniRef50_E7F7X0
# Saved embeddings for UniRef50_A8MBQ3
# Saved embeddings for UniRef50_Q1MTN3
# Saved embeddings for UniRef50_P30713
# Saved embeddings for UniRef50_O74821
# Saved embeddings for UniRef50_P23643
# Saved embeddings for UniRef50_Q86AG8
# Saved embeddings for UniRef50_P74739
# Saved embeddings for UniRef50_O32235
# Saved embeddings for UniRef50_P20485
# Saved embeddings for UniRef50_Q8NB90
# Saved embeddings for UniRef50_Q06709
# Saved embeddings for UniRef50_Q9PNQ6
# Saved embeddings for UniRef50_P54471
# Saved embeddings for UniRef50_Q12383
# Saved embeddings for UniRef50_Q72T26
# Saved embeddings for UniRef50_Q8X071
# Saved embeddings for UniRef50_P0A9I6
# Saved embeddings for UniRef50_P23185
# Saved embeddings for UniRef50_B0CHF1
# Saved embeddings for UniRef50_Q6FKP2
# Saved embeddings for UniRef50_Q05024
# Saved embeddings for UniRef50_O74883
# Saved embeddings for UniRef50_C5DDJ3
# Saved embeddings for UniRef50_Q8UF44
# Saved embeddings for UniRef50_Q47839
# Saved embeddings for UniRef50_A8FHX4
# Saved embeddings for UniRef50_F4IVU1
# Saved embeddings for UniRef50_Q95PZ0
# Saved embeddings for UniRef50_P58315
# Saved embeddings for UniRef50_O13563
# Saved embeddings for UniRef50_P49427
# Saved embeddings for UniRef50_Q6NTJ3
# Saved embeddings for UniRef50_Q03441
# Saved embeddings for UniRef50_Q94587
# Saved embeddings for UniRef50_Q02890
# Saved embeddings for UniRef50_A8F3M5
# Saved embeddings for UniRef50_Q9HC98
# Saved embeddings for UniRef50_Q7VGU1
# Saved embeddings for UniRef50_Q9WY73
# Saved embeddings for UniRef50_Q6C5K4
# Saved embeddings for UniRef50_O83146
# Saved embeddings for UniRef50_P47139
# Saved embeddings for UniRef50_Q24400
# Saved embeddings for UniRef50_Q9SZY8
# Saved embeddings for UniRef50_Q9VL52
# Saved embeddings for UniRef50_Q03336
# Saved embeddings for UniRef50_Q8XBA4
# Saved embeddings for UniRef50_P59567
# Saved embeddings for UniRef50_Q2SDQ4
# Saved embeddings for UniRef50_Q9USY8
# Saved embeddings for UniRef50_O24456
# Saved embeddings for UniRef50_A0LI59
# Saved embeddings for UniRef50_Q99P25
# Saved embeddings for UniRef50_Q97A25
# Saved embeddings for UniRef50_Q8BP71-2
# Saved embeddings for UniRef50_Q9P6N7
# Saved embeddings for UniRef50_Q8GYH7
# Saved embeddings for UniRef50_P61086
# Saved embeddings for UniRef50_Q24167
# Saved embeddings for UniRef50_O51571
# Saved embeddings for UniRef50_B1A193
# Saved embeddings for UniRef50_O94650
# Saved embeddings for UniRef50_Q82EB1
# Saved embeddings for UniRef50_Q9USK5
# Saved embeddings for UniRef50_P80193
# Saved embeddings for UniRef50_A6NNY8
# Saved embeddings for UniRef50_Q9US43
# Saved embeddings for UniRef50_Q9X1N1
# Saved embeddings for UniRef50_C7R403
# Saved embeddings for UniRef50_C7GRQ3
# Saved embeddings for UniRef50_P08153
# Saved embeddings for UniRef50_Q31E86
# Saved embeddings for UniRef50_P60866
# Saved embeddings for UniRef50_B0SK44
# Saved embeddings for UniRef50_A9KH99
# Saved embeddings for UniRef50_Q3Z876
# Saved embeddings for UniRef50_Q9HGP9
# Saved embeddings for UniRef50_Q9FF86
# Saved embeddings for UniRef50_Q729U6
# Saved embeddings for UniRef50_E5FYH1
# Saved embeddings for UniRef50_P19880
# Saved embeddings for UniRef50_P0CZ15
# Saved embeddings for UniRef50_Q12706
# Saved embeddings for UniRef50_Q1LU78
# Saved embeddings for UniRef50_P45349
# Saved embeddings for UniRef50_Q7CQM8
# Saved embeddings for UniRef50_Q9YAW4
# Saved embeddings for UniRef50_P62500
# Saved embeddings for UniRef50_Q9CEH4
# Saved embeddings for UniRef50_Q9CDT7
# Saved embeddings for UniRef50_Q6KIH8
# Saved embeddings for UniRef50_P12348
# Saved embeddings for UniRef50_A9WJ51
# Saved embeddings for UniRef50_D2YW48
# Saved embeddings for UniRef50_P39915
# Saved embeddings for UniRef50_Q05881
# Saved embeddings for UniRef50_Q9C9Y6
# Saved embeddings for UniRef50_Q6MKS2
# Saved embeddings for UniRef50_Q9CZ91
# Saved embeddings for UniRef50_A5DUA3
# Saved embeddings for UniRef50_C5GFG2
# Saved embeddings for UniRef50_Q975G9
# Saved embeddings for UniRef50_P20294
# Saved embeddings for UniRef50_Q9W032
# Saved embeddings for UniRef50_Q0B0A0
# Saved embeddings for UniRef50_Q3Z9F0
# Saved embeddings for UniRef50_Q8A0V4
# Saved embeddings for UniRef50_P53068
# Saved embeddings for UniRef50_O04203
# Saved embeddings for UniRef50_Q9VIF5
# Saved embeddings for UniRef50_O83787
# Saved embeddings for UniRef50_P38986
# Saved embeddings for UniRef50_O13997
# Saved embeddings for UniRef50_P48642
# Saved embeddings for UniRef50_Q8N693
# Saved embeddings for UniRef50_Q8N1E6
# Saved embeddings for UniRef50_P86230
# Saved embeddings for UniRef50_O60271
# Saved embeddings for UniRef50_O74989
# Saved embeddings for UniRef50_Q2RKH8
# Saved embeddings for UniRef50_Q09315
# Saved embeddings for UniRef50_Q7NBX3
# Saved embeddings for UniRef50_O84913
# Saved embeddings for UniRef50_O14033
# Saved embeddings for UniRef50_Q9UUA7
# Saved embeddings for UniRef50_Q6C435
# Saved embeddings for UniRef50_Q7SZK7
# Saved embeddings for UniRef50_Q3IP73
# Saved embeddings for UniRef50_P59328
# Saved embeddings for UniRef50_Q9XYP8
# Saved embeddings for UniRef50_P04181
# Saved embeddings for UniRef50_Q6FQJ4
# Saved embeddings for UniRef50_G3XD76
# Saved embeddings for UniRef50_B1GZN4
# Saved embeddings for UniRef50_Q93EJ3
# Saved embeddings for UniRef50_P25888
# Saved embeddings for UniRef50_B9DTV0
# Saved embeddings for UniRef50_Q55BF2
# Saved embeddings for UniRef50_A9VCY6
# Saved embeddings for UniRef50_Q9AI34
# Saved embeddings for UniRef50_Q9XUC2
# Saved embeddings for UniRef50_O83361
# Saved embeddings for UniRef50_Q4FM95
# Saved embeddings for UniRef50_Q8SRM2
# Saved embeddings for UniRef50_Q0IHJ3
# Saved embeddings for UniRef50_Q6FK59
# Saved embeddings for UniRef50_Q894C9
# Saved embeddings for UniRef50_Q6ZSB9
# Saved embeddings for UniRef50_Q53G44
# Saved embeddings for UniRef50_Q8LE94
# Saved embeddings for UniRef50_Q661V4
# Saved embeddings for UniRef50_O43516
# Saved embeddings for UniRef50_Q7JXF5
# Saved embeddings for UniRef50_Q5ALR8
# Saved embeddings for UniRef50_B9KH69
# Saved embeddings for UniRef50_Q6NT76
# Saved embeddings for UniRef50_Q6CQC6
# Saved embeddings for UniRef50_Q8BZI0
# Saved embeddings for UniRef50_Q6P7L0
# Saved embeddings for UniRef50_Q9LHH7
# Saved embeddings for UniRef50_Q9CGY0
# Saved embeddings for UniRef50_Q03W65
# Saved embeddings for UniRef50_Q9RWN9
# Saved embeddings for UniRef50_Q8RWE8
# Saved embeddings for UniRef50_Q9Z8T3
# Saved embeddings for UniRef50_Q9SUV9
# Saved embeddings for UniRef50_Q3B820
# Saved embeddings for UniRef50_Q1LVV0
# Saved embeddings for UniRef50_P11416-2
# Saved embeddings for UniRef50_Q969H0
# Saved embeddings for UniRef50_Q6FIQ6
# Saved embeddings for UniRef50_Q9NQB0-12
# Saved embeddings for UniRef50_Q1GHT0
# Saved embeddings for UniRef50_Q9ZTK5
# Saved embeddings for UniRef50_A5PLK2
# Saved embeddings for UniRef50_Q6RZZ9
# Saved embeddings for UniRef50_P25359
# Saved embeddings for UniRef50_Q9HCJ3
# Saved embeddings for UniRef50_P29349
# Saved embeddings for UniRef50_Q8AXM9
# Saved embeddings for UniRef50_P29466
# Saved embeddings for UniRef50_P52197
# Saved embeddings for UniRef50_A5FEB8
# Saved embeddings for UniRef50_Q9NRX4
# Saved embeddings for UniRef50_Q76I90
# Saved embeddings for UniRef50_Q2FYR1
# Saved embeddings for UniRef50_Q9SGU9
# Saved embeddings for UniRef50_P0A9F8
# Saved embeddings for UniRef50_P50528
# Saved embeddings for UniRef50_P17052
# Saved embeddings for UniRef50_P40394
# Saved embeddings for UniRef50_Q9VWF4
# Saved embeddings for UniRef50_Q6DFJ6
# Saved embeddings for UniRef50_O74766
# Saved embeddings for UniRef50_Q9UU87
# Saved embeddings for UniRef50_P15977
# Saved embeddings for UniRef50_Q59111
# Saved embeddings for UniRef50_Q9P7X6
# Saved embeddings for UniRef50_Q8N865
# Saved embeddings for UniRef50_P75794
# Saved embeddings for UniRef50_Q88YC0
# Saved embeddings for UniRef50_Q9RRJ4
# Saved embeddings for UniRef50_Q9Y7Q7
# Saved embeddings for UniRef50_Q7NBY7
# Saved embeddings for UniRef50_Q8N2Y8
# Saved embeddings for UniRef50_Q83N13
# Saved embeddings for UniRef50_Q54KF1
# Saved embeddings for UniRef50_B0SPB4
# Saved embeddings for UniRef50_Q9ZKU4
# Saved embeddings for UniRef50_Q8ST62
# Saved embeddings for UniRef50_Q9UKT5
# Saved embeddings for UniRef50_B8H0A3
# Saved embeddings for UniRef50_Q4PEZ0
# Saved embeddings for UniRef50_Q8R778
# Saved embeddings for UniRef50_P22346
# Saved embeddings for UniRef50_Q6QZQ4
# Saved embeddings for UniRef50_A1JT33
# Saved embeddings for UniRef50_Q8TYD6
# Saved embeddings for UniRef50_P16533
# Saved embeddings for UniRef50_O80831
# Saved embeddings for UniRef50_P15442
# Saved embeddings for UniRef50_Q9LU93
# Saved embeddings for UniRef50_P13266
# Saved embeddings for UniRef50_A7I9P7
# Saved embeddings for UniRef50_Q8G5F1
# Saved embeddings for UniRef50_Q9R9H8
# Saved embeddings for UniRef50_Q1IVQ3
# Saved embeddings for UniRef50_Q9PI04
# Saved embeddings for UniRef50_Q59W52
# Saved embeddings for UniRef50_Q7NDJ2
# Saved embeddings for UniRef50_P02247
# Saved embeddings for UniRef50_P46865
# Saved embeddings for UniRef50_P41911
# Saved embeddings for UniRef50_P54005
# Saved embeddings for UniRef50_Q61419
# Saved embeddings for UniRef50_A5DVG6
# Saved embeddings for UniRef50_Q8IZW8
# Saved embeddings for UniRef50_P35510
# Saved embeddings for UniRef50_P38198
# Saved embeddings for UniRef50_Q04377
# Saved embeddings for UniRef50_P46869
# Saved embeddings for UniRef50_P78055
# Saved embeddings for UniRef50_Q9URU2
# Saved embeddings for UniRef50_B2KAM4
# Saved embeddings for UniRef50_Q21WM8
# Saved embeddings for UniRef50_P57357
# Saved embeddings for UniRef50_Q09868
# Saved embeddings for UniRef50_A6ZM92
# Saved embeddings for UniRef50_Q8RDQ2
# Saved embeddings for UniRef50_P09938
# Saved embeddings for UniRef50_A9BHV5
# Saved embeddings for UniRef50_P0DOB6
# Saved embeddings for UniRef50_C1DBX3
# Saved embeddings for UniRef50_Q5K131
# Saved embeddings for UniRef50_A0AFT8
# Saved embeddings for UniRef50_Q9SRY6
# Saved embeddings for UniRef50_Q9PNB8
# Saved embeddings for UniRef50_P32586
# Saved embeddings for UniRef50_Q12182
# Saved embeddings for UniRef50_O42980
# Saved embeddings for UniRef50_Q9FVX0
# Saved embeddings for UniRef50_A2RV06
# Saved embeddings for UniRef50_Q96AB3-2
# Saved embeddings for UniRef50_Q1IVF9
# Saved embeddings for UniRef50_Q8N4J0
# Saved embeddings for UniRef50_Q6FQH3
# Saved embeddings for UniRef50_Q12988
# Saved embeddings for UniRef50_Q16613
# Saved embeddings for UniRef50_Q80X56
# Saved embeddings for UniRef50_P13234
# Saved embeddings for UniRef50_P40316
# Saved embeddings for UniRef50_Q9XYF4
# Saved embeddings for UniRef50_C4XXB1
# Saved embeddings for UniRef50_A9AUT1
# Saved embeddings for UniRef50_Q8NG50
# Saved embeddings for UniRef50_C0QUE5
# Saved embeddings for UniRef50_P49230
# Saved embeddings for UniRef50_Q2M329
# Saved embeddings for UniRef50_Q86VV8
# Saved embeddings for UniRef50_Q9WZ15
# Saved embeddings for UniRef50_P26651
# Saved embeddings for UniRef50_Q96A72
# Saved embeddings for UniRef50_Q9XYP7
# Saved embeddings for UniRef50_P0C1J2
# Saved embeddings for UniRef50_Q6PUR7
# Saved embeddings for UniRef50_Q15398
# Saved embeddings for UniRef50_Q9RTA0
# Saved embeddings for UniRef50_Q9BUP3
# Saved embeddings for UniRef50_P47018
# Saved embeddings for UniRef50_O84030
# Saved embeddings for UniRef50_Q9PC00
# Saved embeddings for UniRef50_P94870
# Saved embeddings for UniRef50_Q59Q38
# Saved embeddings for UniRef50_Q6NZZ9
# Saved embeddings for UniRef50_Q38931
# Saved embeddings for UniRef50_Q4I963
# Saved embeddings for UniRef50_Q94CE5
# Saved embeddings for UniRef50_O14192
# Saved embeddings for UniRef50_Q2NEP8
# Saved embeddings for UniRef50_Q23AS2
# Saved embeddings for UniRef50_B0R5M0
# Saved embeddings for UniRef50_B6INM0
# Saved embeddings for UniRef50_A5DLN4
# Saved embeddings for UniRef50_Q6KH82
# Saved embeddings for UniRef50_Q73H02
# Saved embeddings for UniRef50_Q7RTS9
# Saved embeddings for UniRef50_Q9FLT0
# Saved embeddings for UniRef50_A5FAX4
# Saved embeddings for UniRef50_C8V3W6
# Saved embeddings for UniRef50_O60760
# Saved embeddings for UniRef50_Q54MZ9
# Saved embeddings for UniRef50_Q43963
# Saved embeddings for UniRef50_G0SEH7
# Saved embeddings for UniRef50_Q9V076
# Saved embeddings for UniRef50_P21375
# Saved embeddings for UniRef50_Q9I452
# Saved embeddings for UniRef50_O81635
# Saved embeddings for UniRef50_A7HBQ0
# Saved embeddings for UniRef50_Q19LA2
# Saved embeddings for UniRef50_Q49112
# Saved embeddings for UniRef50_Q54Y96
# Saved embeddings for UniRef50_Q59W62
# Saved embeddings for UniRef50_Q0SMS3
# Saved embeddings for UniRef50_O13921
# Saved embeddings for UniRef50_Q75EQ0
# Saved embeddings for UniRef50_Q6XVY3
# Saved embeddings for UniRef50_Q28PK5
# Saved embeddings for UniRef50_Q9PQ74
# Saved embeddings for UniRef50_B1VSW8
# Saved embeddings for UniRef50_P45450
# Saved embeddings for UniRef50_Q557H7
# Saved embeddings for UniRef50_B3LR49
# Saved embeddings for UniRef50_G4RK16
# Saved embeddings for UniRef50_Q08285
# Saved embeddings for UniRef50_Q8LDI5
# Saved embeddings for UniRef50_Q117Z6
# Saved embeddings for UniRef50_Q057N0
# Saved embeddings for UniRef50_Q96JB5
# Saved embeddings for UniRef50_B1AJ32
# Saved embeddings for UniRef50_O94338
# Saved embeddings for UniRef50_P25298
# Saved embeddings for UniRef50_Q6FU75
# Saved embeddings for UniRef50_Q0K845
# Saved embeddings for UniRef50_Q8K9Q3
# Saved embeddings for UniRef50_A8Z5X3
# Saved embeddings for UniRef50_O05974
# Saved embeddings for UniRef50_Q5S003
# Saved embeddings for UniRef50_A3CTR9
# Saved embeddings for UniRef50_Q7VP59
# Saved embeddings for UniRef50_P42845
# Saved embeddings for UniRef50_Q9VJ29
# Saved embeddings for UniRef50_A6TB83
# Saved embeddings for UniRef50_Q9BUB5
# Saved embeddings for UniRef50_P55992
# Saved embeddings for UniRef50_Q8UGA9
# Saved embeddings for UniRef50_Q9KKJ5
# Saved embeddings for UniRef50_A5UJV0
# Saved embeddings for UniRef50_Q54FM4
# Saved embeddings for UniRef50_O94562
# Saved embeddings for UniRef50_O74454
# Saved embeddings for UniRef50_O59719
# Saved embeddings for UniRef50_A8IRK7
# Saved embeddings for UniRef50_Q54CE0
# Saved embeddings for UniRef50_O58263
# Saved embeddings for UniRef50_A7TEW6
# Saved embeddings for UniRef50_Q9SV36
# Saved embeddings for UniRef50_P85120
# Saved embeddings for UniRef50_O70263
# Saved embeddings for UniRef50_Q58925
# Saved embeddings for UniRef50_Q7Z4T9-7
# Saved embeddings for UniRef50_Q96AB6
# Saved embeddings for UniRef50_Q8D226
# Saved embeddings for UniRef50_Q55GA0
# Saved embeddings for UniRef50_Q09501
# Saved embeddings for UniRef50_C4K4P3
# Saved embeddings for UniRef50_P0CS10
# Saved embeddings for UniRef50_Q6NH03
# Saved embeddings for UniRef50_Q9USI4
# Saved embeddings for UniRef50_Q9USU1
# Saved embeddings for UniRef50_Q9P6I6
# Saved embeddings for UniRef50_Q9Y4F5
# Saved embeddings for UniRef50_O67753
# Saved embeddings for UniRef50_Q8UEY3
# Saved embeddings for UniRef50_P21787
# Saved embeddings for UniRef50_Q12180
# Saved embeddings for UniRef50_O83047
# Saved embeddings for UniRef50_Q8IZY5
# Saved embeddings for UniRef50_Q6MH10
# Saved embeddings for UniRef50_B7TWP7
# Saved embeddings for UniRef50_Q8SRI3
# Saved embeddings for UniRef50_P0CN45
# Saved embeddings for UniRef50_Q8EZ61
# Saved embeddings for UniRef50_Q7CHK5
# Saved embeddings for UniRef50_F4I3Z5
# Saved embeddings for UniRef50_A5FC30
# Saved embeddings for UniRef50_Q9RUP6
# Saved embeddings for UniRef50_Q54YY1
# Saved embeddings for UniRef50_Q726S7
# Saved embeddings for UniRef50_Q9S745
# Saved embeddings for UniRef50_Q8ZKU8
# Saved embeddings for UniRef50_Q1DD74
# Saved embeddings for UniRef50_Q980I9
# Saved embeddings for UniRef50_Q8GW43
# Saved embeddings for UniRef50_O04147
# Saved embeddings for UniRef50_O45487
# Saved embeddings for UniRef50_O34851
# Saved embeddings for UniRef50_O28578
# Saved embeddings for UniRef50_Q95ZK7
# Saved embeddings for UniRef50_O59748
# Saved embeddings for UniRef50_P05153
# Saved embeddings for UniRef50_Q8FT24
# Saved embeddings for UniRef50_P71590
# Saved embeddings for UniRef50_Q5SW96
# Saved embeddings for UniRef50_O94992
# Saved embeddings for UniRef50_A8F732
# Saved embeddings for UniRef50_Q2J827
# Saved embeddings for UniRef50_Q9C026-4
# Saved embeddings for UniRef50_Q9UNP9
# Saved embeddings for UniRef50_A8QBB1
# Saved embeddings for UniRef50_P53256
# Saved embeddings for UniRef50_Q1GVM5
# Saved embeddings for UniRef50_P52023
# Saved embeddings for UniRef50_Q9NYB0
# Saved embeddings for UniRef50_Q13045
# Saved embeddings for UniRef50_Q8WUF5
# Saved embeddings for UniRef50_Q7SD63
# Saved embeddings for UniRef50_O76041
# Saved embeddings for UniRef50_Q96C86
# Saved embeddings for UniRef50_Q9VCI3
# Saved embeddings for UniRef50_P43255
# Saved embeddings for UniRef50_Q8JGN5
# Saved embeddings for UniRef50_A8FK97
# Saved embeddings for UniRef50_P14708
# Saved embeddings for UniRef50_P95855
# Saved embeddings for UniRef50_P76536
# Saved embeddings for UniRef50_Q1RM35
# Saved embeddings for UniRef50_Q9Z4Q7
# Saved embeddings for UniRef50_Q75CK5
# Saved embeddings for UniRef50_O14019
# Saved embeddings for UniRef50_A0RUR7
# Saved embeddings for UniRef50_O95835
# Saved embeddings for UniRef50_Q8ETB7
# Saved embeddings for UniRef50_Q9VYA8
# Saved embeddings for UniRef50_O43029
# Saved embeddings for UniRef50_Q13098
# Saved embeddings for UniRef50_Q8KGG6
# Saved embeddings for UniRef50_P24094
# Saved embeddings for UniRef50_Q5B0Y2
# Saved embeddings for UniRef50_Q7UMW0
# Saved embeddings for UniRef50_Q9LWN0
# Saved embeddings for UniRef50_O80856
# Saved embeddings for UniRef50_Q7UFX8
# Saved embeddings for UniRef50_Q9ZVC2
# Saved embeddings for UniRef50_Q4K8U2
# Saved embeddings for UniRef50_Q9W1F4
# Saved embeddings for UniRef50_Q8W2B8
# Saved embeddings for UniRef50_P35415
# Saved embeddings for UniRef50_Q8GND0
# Saved embeddings for UniRef50_Q2FQU2
# Saved embeddings for UniRef50_P27695
# Saved embeddings for UniRef50_Q7RX33
# Saved embeddings for UniRef50_Q9BKZ9
# Saved embeddings for UniRef50_Q6CLD3
# Saved embeddings for UniRef50_B2KCP2
# Saved embeddings for UniRef50_Q2LKU9
# Saved embeddings for UniRef50_A1TC40
# Saved embeddings for UniRef50_Q5NZF6
# Saved embeddings for UniRef50_Q9US52
# Saved embeddings for UniRef50_P36159
# Saved embeddings for UniRef50_Q9US35
# Saved embeddings for UniRef50_Q6AL12
# Saved embeddings for UniRef50_P10383
# Saved embeddings for UniRef50_P91276
# Saved embeddings for UniRef50_Q54XP2
# Saved embeddings for UniRef50_Q6LA56
# Saved embeddings for UniRef50_Q9H425
# Saved embeddings for UniRef50_Q9S7U5
# Saved embeddings for UniRef50_C4R6H3
# Saved embeddings for UniRef50_Q5A961
# Saved embeddings for UniRef50_P32047
# Saved embeddings for UniRef50_O94916
# Saved embeddings for UniRef50_P57279
# Saved embeddings for UniRef50_P53250
# Saved embeddings for UniRef50_Q9I742
# Saved embeddings for UniRef50_Q7VRE3
# Saved embeddings for UniRef50_O94258
# Saved embeddings for UniRef50_A9GP79
# Saved embeddings for UniRef50_Q46338
# Saved embeddings for UniRef50_O31601
# Saved embeddings for UniRef50_Q8VMM5
# Saved embeddings for UniRef50_P17695
# Saved embeddings for UniRef50_Q9UJT0
# Saved embeddings for UniRef50_B3QZW6
# Saved embeddings for UniRef50_O42654
# Saved embeddings for UniRef50_Q118E6
# Saved embeddings for UniRef50_Q96T76
# Saved embeddings for UniRef50_P87244
# Saved embeddings for UniRef50_Q5XK85
# Saved embeddings for UniRef50_Q753F1
# Saved embeddings for UniRef50_Q13939
# Saved embeddings for UniRef50_Q14807
# Saved embeddings for UniRef50_O94265
# Saved embeddings for UniRef50_O94664
# Saved embeddings for UniRef50_Q7RTR2
# Saved embeddings for UniRef50_Q55DB6
# Saved embeddings for UniRef50_Q72R21
# Saved embeddings for UniRef50_Q01W33
# Saved embeddings for UniRef50_Q6P2E9
# Saved embeddings for UniRef50_Q13322
# Saved embeddings for UniRef50_O73673
# Saved embeddings for UniRef50_Q05AL2
